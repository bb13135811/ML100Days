# %% [markdown]
# # [作業目標]
#
#
# 1. [簡答題] 比較下列兩個讀入的 df 有什麼不同？為什麼造成的？
#
# 2. 請將 Dcard API 取得所有的看板資訊轉換成 DataFrame，並且依照熱門程度排序後存成一個 csv 的檔案。

# %% [markdown]
# # 作業

# %%
# 記得先 Import 正確的套件

import numpy as np
import pandas as pd

# %% [markdown]
# ### 1. [簡答題] 比較下列兩個讀入的 df 有什麼不同？為什麼造成的？

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/dataoptimal/posts/master/data%20cleaning%20with%20python%20and%20pandas/property%20data.csv')
df1
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY           12            1      NaN   700
# 4          NaN   203.0    BERKELEY            Y            3        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0     NaN  WASHINGTON          NaN            2   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y            1        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800

# %%
df2 = pd.read_csv(
    'https://raw.githubusercontent.com/dataoptimal/posts/master/data%20cleaning%20with%20python%20and%20pandas/property%20data.csv',
    keep_default_na=True,
    na_values=['na', '--']
)
df2
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5     NaN
# 2  100003000.0     NaN   LEXINGTON            N           NaN        1   850.0
# 3  100004000.0   201.0    BERKELEY           12           1.0      NaN   700.0
# 4          NaN   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN        1   800.0
# 6  100007000.0     NaN  WASHINGTON          NaN           2.0   HURLEY   950.0
# 7  100008000.0   213.0     TREMONT            Y           1.0        1     NaN
# 8  100009000.0   215.0     TREMONT            Y           NaN        2  1800.0

# %%
df2自訂df1中缺失值

# %% [markdown]
# ### 2. 請將 Dcard API 取得所有的看板資訊轉換成 DataFrame，並且依照熱門程度排序後存成一個 csv 的檔案。

# %%
import requests
r = requests.get('https://www.dcard.tw/_api/forums')
response = r.text

import json
data = json.loads(response)

# %%
df = pd.DataFrame(data)
df = df.drop(axis=1, columns= 'id')
df = df.sort_values(by=['subscriptionCount'], ascending=False)
df.to_excel('dcard.xlsx')

# %%
for i in df['topics']:
    print(i)
# Out:
# ['A片', '甲', 'Les', '無碼片', 'NTR', '內射', '自慰', '3P', '外流', '意淫自拍OL黑絲', '玩具大賞', '情趣用品', '大雞雞', '保險套', '約炮', 'H漫', '調教', '潤滑液', '做愛']
# ['微西斯', '愛情', '閃光', '價值觀', '告白', '分手', '遠距離', '失戀', '曖昧', '做愛', '在一起', '學長', '交友軟體', '七夕', '單身', '渣男', '第一次', '同居', '暗戀', '復合', '木頭男友', '綠帽', '撒嬌', '劈腿', '大叔', '脫魯', '同事', '情人節', '菜桃貴', '一個人', '生理期', '約會', '月老', '警察', '熱戀期', '學妹', '旅行', '生日禮物']
# ['蝦皮', '耳環', '襯衫', '工裝', '後背包', '寬褲', '淘寶', '涼鞋', '洋裝', '情侶穿搭', '鞋子', '韓系穿搭', '背包', '眼鏡', '白襯衫', '牛仔褲', '腰包', '日系穿搭', '餅乾鞋', '外套', '背心', '長夾', '古著', '女生穿搭', '男生穿搭', '日常穿搭', '肉肉女穿搭', '雨衣', '小隻女穿搭', '真理褲', '校園穿搭', '帆布鞋', '歐美風', '球鞋', 'Converse', '中性穿搭', '顯瘦穿搭', '婚禮穿搭', '泳裝', '約會穿搭', '罩衫', '重複穿搭', '姊妹穿搭', '復古風']
# ['潔膚水', '防曬', '粉餅', '受受狼', '刷具', '遮瑕', '粉刺', '打亮', '眼影', '粉底', '眉筆', '粉底液', '美白', '隱眼', '蜜粉', '面膜', '眼線', '修容', '二手拍', '唇膏試色', '眉毛', '保養', '日常妝容', '唇彩', '底妝', '敏感肌', '口紅', '腮紅', '眼妝', '凹凹賞', '空空賞', '指甲油', '男生保養', '約會妝容', '開架彩妝', '香水', '醫美']
# []
# ['台中美食', '高雄美食', '台南美食', '台北美食', '新竹美食', '板橋美食', '全聯', '711', '嘉義美食', '全家', '花蓮美食', '屏東美食', '貓咪咖啡廳', '宜蘭美食', '桃園美食', '學餐', '肯德基', '超商', '全聯牛奶糖季', '甜點', '台中美食', '銅板美食', '燒烤', '外國學餐', '嘉義美食', '手搖飲', '早午餐', '居酒屋', '餐飲店員告訴你', '下午茶', '飛機餐', '火鍋', '自助餐', '咖啡廳', '調酒']
# ['心理測驗', '占卜', '雙魚', '射手', '天蠍', '雙子', '巨蟹', '白羊', '金牛', '水瓶', '獅子', '處女', '天秤', '摩羯']
# ['網美媽媽', '廢墟探險', '畢旅', '童年回憶', '泰國浴', '租屋', '牙套', '法律', '困擾', '醫療']
# ['校正回歸']
# ['信用卡', '基金', '股票期貨', '虛擬貨幣', '匯率', '儲蓄險', '保險', '比特幣', '投資']
# ['笑話', '梗圖', 'Wootalk', '愛莉莎莎', '黃金12猛漢', '撩妹', '微西斯', '貼圖', '網紅', '火柴人', '您還親切的問我要冰還熱', '傻眼', '奶奶好可愛', '這年頭的香腸都喜歡玩躲貓貓', '搞笑', '童年回憶', '撩妹語錄', '糗事', '惡搞', '接龍', '宿舍生活', '有趣日常']
# ['心事', '男友', '比基尼', '除毛', 'WhatsInMyBag', '內衣', '家人', '發胖', '桌布', '懷孕', '處女膜', '減肥', '第一次', '健身', '相處', '改造', '約炮', '月經', '小胸女孩', '手機桌布', '私密處', '疫苗', '霧眉', '念珠菌', '分手禮', '陰道冠', '豐胸', '韓服', '精品', '大胸女孩', '牙套', '夜店', '後背包', '皮膚科', '短夾', '棉條', '吊飾', '雙眼皮', '無肩帶內衣']
# ['女大十八變', '租屋糾紛', '畢旅', '感動的事', '一句晚安', '想念你', '謝謝你', '靠北', '勵志', '情緒勒索', '霸凌', '憂鬱症']
# []
# ['Netflix', '影集', '美劇', '電影', '推薦', '觀後感']
# ['領養代替購買', '米克斯', '貓', '狗', '柯基', '柴犬', '認養', '貓咪真的很可愛', '動物醫院', '寵物美容', '結紮', '寵物店', '鳥', '兔', '魚', '刺蝟', '植物', '驅蟲', '疫苗']
# ['生酮飲食', '減脂', '乳清', '增肌', '健身器材', '健身房', '重訓', '臥推', '熱量', '啞鈴', '有氧', '深蹲', '減重', '蛋白質', '伏地挺身', '胸肌', '健美', '腹肌', '肌肉']
# ['飲食', '運動', '勵志']
# ['面試經驗', '2020聯合校徵', '面試心得', '面試小技巧', '履歷教學', '航空業', 'Askmeanything', '應屆畢業生', '員工餐', '工作經驗', '空服員', '面試', '慣老闆', '奧客', '勞工權益', '勞基法', '薪資', '履歷', '打工職缺', '實習職缺', '試用期', '離職', '徵才', '實習']
# []
# ['優惠', '已兌換', '買一送一', '生日優惠', '折價券', '折扣碼']
# ['WhatsInMyRoom', '居家佈置', '空間風格', '租屋', '室內香氛', '家具', '輕裝潢', '收納', '租屋糾紛']
# ['影評', 'MARVEL系列', '迪士尼', 'DC系列', '觀後感', '電影院', '奧斯卡獎', '預告片', '動畫', '真人版', '宮崎駿', '韓國電影', '日本電影', '歐美電影', '經典電影', '印度電影', '驚悚片', '紀錄片']
# ['畢旅', '自由行', '賞楓', '海外志工', '台灣秘境', '臥鋪火車', '獨旅', '飛機餐', '沙發衝浪', '韓國', '穿旗袍遊台南', '首爾', '自由行', '展覽', '畢旅', '泰國浴', '泰國', '環島', '景點', '郵輪', '網卡', '香港自由行', '地鐵', '遊記', '大阪', '青年旅舍', '旅行社', '跟團', '行李箱', '租車', '機票', '護照', '簽證', '打工度假', '廉航', '打工換宿']
# ['地獄梗', 'meme', '梗圖', '冷笑話']
# ['料理', '提問', '廚具', '烹飪', '食譜', '小資料理']
# ['微西斯', '高馬尾和長直髮', 'PPL', '早知道系列', 'Les', '天菜老師', '總在夜半消失的室友學長', '甲', 'TPL', '百合小說', '床上運動', '發情的公狗', 'Vincent', '告白', '直女', '師生戀', '交友軟體', '暖暖日常', '直男', '我們來認真的談一場戀愛', '喬薇', '長髮冰山學姐X短髮忠犬學妹', '出櫃', '性事', '姐姐很可愛', '同婚', '深櫃', '做愛', '天菜', '初吻', '跨性別', '無性戀']
# ['AppleLearn', 'AppleWork', 'Mac', 'iPad']
# ['網購教學', '淘寶', '退貨', '蝦皮', '支付寶', '賣家', '集運運費', '官方集運', '私人集運', '購物金', '物流', '假貨']
# ['短髮', '燙髮', '剪髮', '護髮油', '編髮造型', '染髮', '洗髮乳', '吹風機', '護髮', '潤髮乳']
# ['蠟筆小新', '庫洛魔法使', '聲之形', '動漫展', '初音未來', 'Cosplay', '動漫周邊', '動漫歌單', '推坑', '新番', '聲優', '名偵探柯南', '漫畫家', '動畫化', '恐怖漫畫', 'Vocaloid', '童年回憶', '真人版', '輕小說', 'MAD', '聖地巡禮', '同人']
# ['EXO', 'Apink', 'ITZY', '周子瑜', 'SEVENTEEN', '手燈', 'NCT', '賴冠霖', 'AB6IX', 'IU', '武林', 'BTS', 'YouTuber', '專輯', 'TWICE', '王一博', 'MAMAMOO', '韓星', 'GOT7', '姜丹尼爾', 'PRODUCEX101', '防彈少年團', 'RedVelvet', 'IZONE', 'GFRIEND', 'BTOB', 'Somi', 'StrayKids', 'IOI', '曹承衍', 'AB6IX', 'NUEST', 'SuperJunior']
# ['動物森友會', '戀與製作人', '閃耀暖暖', '跑跑薑餅人', '極速領域', '傳說對決', '第五人格', '遇見逆水寒', '遊戲序號', '爆爆王M', '新楓之谷', 'FGO', '還願', 'Steam', 'Switch', '手遊', 'Overwatch', '攻略', '小遊戲', '課金', '單機遊戲', 'PS4', 'LOL', '魔物獵人', '電競', '遊戲實況', '桌遊']
# ['都市傳說', '廢墟探險', '佛牌', '護身符', '親身經歷', '海龜湯', '真實故事', '靈異板系列文']
# ['乾燥花', '爆炸盒', '袖珍屋', '羊毛氈', '飲料提袋', '模型', '手寫', '鋼筆', '手繪', '電繪', '摺紙', '縫紉', '刺繡', '毛線', '手帳', '黏土', '雕刻', '噴漆', '印章', '插畫', '木工', '金工', '水彩', '素描', '皮件', '編織', '書法', '袖珍']
# ['校正回歸', '口罩', '防疫', 'COVID19']
# ['netflix', '木曜4超玩', '綜藝玩很大', '八點檔', '台劇', '後宮甄嬛傳', '植劇場', '日劇', '韓劇', '美劇', '陸劇', '泰劇', '韓綜', '日綜', '台綜', '陸綜', '偶像劇', 'RunningMan']
# ['夜景', '底片', '手機攝影', '攝影作品', '單眼', '鏡頭', '人像攝影', '街拍', '快門', '調色', '修圖', '相機', '照片', '日出', '街頭攝影', '作品', '旅遊', '疫情', '底片相機', '新手']
# []
# ['登記分發', '指考', '重考生', '轉學考', '國考', '考古題', '參考書', '普考', '特考', '研究所', '夜校', '夜間部', '推甄', '學測', '統測', '指考', '成績單', '正取', '繁星', '申請', '補習班', '獨招']
# ['成人', '色情文學', '情色文學', '西斯文學']
# ['機車', '汽車', '中古車', 'Gogoro', '二手車', '安全帽', '機車駕照', '汽車駕照', '行車記錄器', '改裝', '機油', '車禍', '車牌', '駕照', '監理站', '重機', '加油', '輪胎', '租車', '煞車', '路考', '國道', '引擎']
# []
# ['占卜', '感情', '塔羅測驗']
# ['純愛', 'NTR']
# ['WhatsOnMyPhone', '機械式鍵盤', '藍牙耳機', '手機桌布', '手機維修', '電腦維修', '電腦', '手機殼', '筆電', '鍵盤', '滑鼠', '顯卡', '行動電源', '輸入法', 'HDMI', '音響', '處理器', 'Windows', 'MacBook', 'Android', 'iOS', 'iPhone', 'iCloud', 'Siri', 'NFC', '充電器', 'COMPUTEX', 'WWDC', '充電線', 'USB', '路由器', '主機', '網速', 'iPad']
# []
# ['婚姻生活', 'OhMyWedding', '寶寶日記', '婚紗', '海外婚禮', '婚禮小物', '我是媽媽', '聘金', '求婚', '懷孕', '裸婚', '外遇']
# []
# ['日檢', '英語', '日語', '韓語', '翻譯', '歐語', '越南語', '動詞', '多益', '雅思', '托福', '日檢', 'TOPIK', '寫作', '字幕', '俄文', '漢字', '字典', '語言學', '第二外語', '德文', '檢定', '自學', '教材']
# ['核卡', '現金回饋', '哩程', 'VISA', 'JCB']
# []
# []
# ['我的線上畢典', '選系雷達', '新生季懶人包', '選校', '選系', '落點', '指考', '宿舍用品', '人際關係', '學長幫幫我', '學姊幫幫我', '統測', '新生', '大學', '推甄', '備審資料', '筆電', '高科大', '中科大']
# ['歐美影集', 'Netflix', '心得分享']
# []
# ['鮮奶茶', '奶茶', '烏龍茶', '珍珠奶茶', '手搖飲', '螞蟻人', '珍珠控']
# ['金曲獎', '找歌', '音樂創作', '演唱會', '獨立音樂', '電子音樂', 'Cover', '中國新說唱', '空耳', '西洋音樂', '日文歌', '韓文歌', '古典音樂', '原聲帶', '饒舌', '吉他', '歌單', '歌詞', '五月天', 'KTV', '我是歌手', '唱片', '華語歌']
# ['留學生活', '簽證', '語言學校', '獎學金', '交換學生', '遊學', 'GPA', '留學申請', '留學考試', '德國留學', '音樂學院', '美國留學', '社區大學', '美國大學', '韓國留學', '日本留學', '英國留學', '英國大學', '韓國大學', '綠卡', '留學生']
# ['找片', '野裸', '控射', 'BDSM', '熊', '多人', '鞋襪', '情趣', '鮮肉', '大叔', '腿控', '喜好', '正太', '性生活']
# []
# []
# []
# ['置頂公告']
# []
# ['NIKE', 'ADIDAS', 'REEBOK', 'PUMA', 'CONVERSE', 'NB', '聯名']
# ['調酒', '酒吧', '威士忌', '紅酒', '品酒', '酒']
# ['言情小說', '尋書', '愛情', '原創小說', '原創', '言情', '創作', 'BL小說', '找書']
# ['言情小說', '書店', '二手書', '恐怖小說', '小說', '科幻小說', '散文', '書單', '推理小說', '作家', '東野圭吾', '奇幻小說', '穿越小說', '金庸', '原創小說', '輕小說', '繪本', '原文書', '武俠小說']
# []
# ['重機', '檔車', '輕檔車', '重機板', '機車']
# []
# []
# []
# ['巧克力']
# ['NBA', 'NBA數據', '湖人BOX', '快艇BOX', '公鹿BOX', '塞爾提克BOX', '暴龍BOX', '熱火BOX', '雷霆BOX', '火箭BOX', '金塊BOX', '籃球', '湖人', '季後賽', 'LBJ', '爵士', '籃網', '太陽', '快艇']
# ['日劇', '推薦', '分享', '心得']
# ['超商版重要通知', '小七', '全家', '思樂冰', '霜淇淋', '711']
# ['文具板', '文具控', '文具展', '文具', '鋼筆', '手帳', '紙膠帶', '拼貼']
# []
# ['實習', '薪資', '醫院宿舍', '單位', '臨床', '面試', '國考']
# []
# ['NBA', 'UBA', 'HBL', '林書豪', '瓊斯盃', 'JR', 'SBL', 'LBJ', '寶島夢想家']
# ['分享', '教學']
# ['音樂祭', 'punk', 'hiphop', 'folk', 'blues', 'rock', 'funk', 'jazz', 'dreampop', 'citypop', '農農', '法蘭黛', '落日飛車', '懷孕飛車']
# ['CoffeeReview', '咖啡', '拿鐵', '摩卡', '卡布奇諾', '美式', '黑咖啡', '手沖', '賽風壺', '義式咖啡', '濃縮咖啡', '單品', '濾杯', '磨豆機', '豆子']
# ['韓綜', '綜藝節目']
# ['米糕麻麻的公告', '阿米手冊', '板規說明']
# ['動物森友會', '島民', 'switch', '任天堂', '動森', '動物之森', '動森主機']
# []
# ['飛機餐', '飛行紀錄', '地勤', '空服員', '航空', '培訓機師']
# ['教養問題', '懷孕', '寶寶日記']
# []
# ['麥當勞', '摩斯', '肯德基', '優惠券']
# []
# ['優惠', '行動支付', '閒聊', '分享']
# ['男生保養', '兵變', '新訓', '男用香水', '當兵', '替代役', '學長幫幫我', '撩妹', '戒尻', '國軍', '表特', '入伍', '鬍子', '長高', '痘痘']
# ['小新', '小葵', '小白', '美冴', '廣志', '阿呆', '正男', '妮妮', '風間', '快閃店']
# []
# []
# []
# ['面試經驗', '2020聯合校徵']
# ['馬拉松', '游泳', '滑板', '登山', '攀岩', '潛水', '慢跑', '運動內衣', '運動彩券', '物理治療', '運動傷害', '排球', '歐冠', 'FIFA', '球拍', '啦啦隊', '體操', '奧運', '冬季奧運']
# ['手寫', '手寫的溫度', '鋼筆', '新詩', '詩詞']
# ['創業歷程', '創業', '創業分享', '投資']
# ['隕石開發', '碼農', 'k8s', 'tensorflow', 'python']
# []
# ['工作', '考試', '健保', 'Askmeanything', '活動', '武漢肺炎', 'COVID19', '疫情', '時事', '醫檢師', '醫事人員板', '醫學系', '醫院']
# []
# ['攻略', '道館', '色違', 'IV', '團戰', '星塵', '雷達', '進化', '快龍', '皮卡丘', '卡比獸', '神奇寶貝球']
# []
# ['限塑政策', '不鏽鋼吸管', '玻璃吸管', '食物浪費', '無痕飲食', '月亮杯', '剩食餐廳', '衛生紙', '回收', '環保杯套', '食物袋', '徒步環島', '保鮮盒', '衛生棉條', '世界地球日']
# ['BL原創', 'CP', '創作', '越界', '廣播劇', 'BL推坑', '腐', '圖', '耽美', '虐', '攻受', '腐女', '腐男', '同人', '書單', 'BL漫畫', 'BL小說', '作者', '正太', '真人']
# []
# ['區塊鏈', '加密貨幣']
# []
# ['板規', 'Les']
# []
# ['洞八', '官校生', '國家國家', '親愛精誠']
# ['高雄美食', '高雄旅遊']
# []
# []
# []
# ['適合聽音樂的活動', '音樂祭']
# ['澳洲', '英國', '美國', '歐洲', '海外工作', '菲律賓']
# ['switch']
# ['新詩', '散文', '小說', '詞創']
# []
# ['研究所', '補習班', '微積分', '程式語言', '通識', '選修', '必修']
# ['citrus', '百合漫畫', '百合小說']
# ['BLACKPINK', 'Lisa', 'Rose', 'Jennie', 'Jisoo', '追星', '韓星']
# ['自由潛水']
# []
# ['偽娘']
# ['韓國留學', '韓國', '交換學生', '留學生', '留學生活', '打工', '語學堂']
# ['中華職棒', '中信兄弟', 'Lamigo桃猿', 'CPBL', 'MLB', '陳偉殷', '日職', 'WBC', '統一獅', '富邦悍將']
# ['多肉', '蕨類', '請益', '多肉植物', '園藝', '新手', '仙人掌', '居家佈置', '盆栽']
# []
# ['建築轉學考', '建築軟體', '事務所']
# []
# []
# ['素食', '美食', '旅遊', '愛動物', '環保', '極簡', '無痕生活']
# []
# []
# ['討論區', '五月天演唱會', '五迷']
# []
# ['民法', '刑法', '憲法', '行政法', '國考']
# []
# []
# []
# ['EXO', 'WeAreONE']
# ['公告']
# []
# []
# ['歐洲', '北歐', '德國', '荷蘭', '法國', '歐洲生活', '歐洲旅遊', '留學', '求職', '海外工作']
# []
# ['國營考試']
# []
# ['學士服', '畢業典禮', '畢業照', '畢業歌', '畢業花束', '畢業禮物', '畢旅', '應屆畢業生', '畢業', '畢冊', '社會新鮮人', '學士帽', '學士照']
# ['TWICE', 'ONCE', '追星', '愛之味', '子瑜', '舞台', 'AlcoholFree', '專輯', '韓星']
# []
# []
# ['Dcard聖誕列車', '交換禮物', '聖誕禮物', '聖誕卡片', '聖誕舞會', '聖誕樹', '聖誕節']
# []
# []
# ['教師', '教檢']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['美食', '美甲', '重機', '烹飪', '星座']
# ['卡娜赫拉', 'Kanahei', '卡娜赫拉老師', '卡娜赫拉板']
# []
# ['不見面在一起', '居家防疫', '防疫']
# ['小天使公告', 'Dcard新功能', '開板連署文']
# []
# []
# []
# []
# ['登山', '新手', '爬山']
# []
# []
# ['餐飲', '奧客', '心得', '面試', '討論']
# ['亞運', '世大運']
# ['小事公益', '領養代替購買', '環保餐具', '不浪費食物', '街賣者', '謝謝你辛苦了', '愛要及時']
# []
# []
# ['扑野', '18禁', 'SEX']
# []
# []
# []
# ['黃金蘋果', '時尚隨機箱', '皇家美髮整形', '新楓之谷', '楓之谷', '楓之谷M', '楓谷', '楓之谷板', '新手']
# []
# []
# []
# []
# ['藍芽耳機', '耳機線', '喇叭', '電視']
# ['NCT', 'NCT127', 'NCTDream', 'WayV', '追星']
# ['Android']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['天竺鼠車車']
# []
# ['新手球迷指南', '英超', '歐冠', '球隊介紹', '轉會市場', '德甲', '西甲', '運動彩券', '法國隊', '賽事分析', 'Mbappe', '英格蘭隊', '梅西', '孫興慜', '阿根廷隊', 'C羅', '冰島', 'FIFA', '比利時隊', '西葡大戰', '世足16強賽', '內馬爾', '巴西隊', '烏龍球', '烏拉圭隊', '德國隊', '日本隊']
# []
# []
# []
# []
# []
# []
# []
# []
# ['心得', '攻略', 'PS5', 'PS4', '新聞', 'PlayStation']
# []
# ['Steam', 'EA', 'Origin']
# []
# []
# ['演員', '模特兒', '歌手', '聲優', '偶像']
# []
# ['蛇', '守宮', '蜥蜴', '龜', '兩棲']
# []
# []
# []
# ['靠北老闆', '靠北奧客']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['教學', '金光', '討論', '公告', '情報']
# []
# []
# []
# ['電競', '實況', 'Twitch', 'YoutubeGaming', 'FacebookGaming', '直播', '嗨賴']
# []
# []
# ['行車記錄器']
# []
# []
# []
# []
# []
# []
# []
# ['溫網', '澳網', '法網', '美網', '拉沃盃']
# []
# []
# []
# ['泰劇', '泰星', '泰國電影', '音樂', '爆雷', '討論', '分享']
# []
# []
# []
# ['JUPAS', 'asso', 'year1', 'freshman', '升學', 'DSE']
# []
# []
# []
# []
# []
# ['身障', '輔具', '聽障', '心情', '視障', '肢障', '資訊', '憂鬱症', '精神疾病', '憂鬱', '心理']
# []
# []
# []
# []
# []
# ['表白', '香港', '拍拖', '單身', '感情', 'A0']
# ['SHINee', '溫流', '鐘鉉', 'KEY', '珉豪', '泰民']
# ['乃木坂46板公告', '乃木坂46', '日向坂46', '櫻坂46', '欅坂46']
# []
# []
# []
# ['白起', '李澤言', '許墨', '周棋洛', '抽卡', '陸服']
# []
# []
# []
# ['SKY光遇', '徵友', '光遇', '互火', '日常', '季票', '小王子', '新手', '互心互火', '景點']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['僑生']
# []
# ['上莊', 'hall', 'Ulife', 'Sem', '大學']
# []
# []
# ['煩惱', '香港', '女仔', '心事']
# []
# []
# []
# ['性傾向', '跨性別', 'LGBT', '同性戀']
# []
# []
# []
# []
# ['情報', '更新', '徵人', '分享']
# []
# []
# []
# []
# []
# ['布袋戲']
# []
# []
# []
# []
# []
# []
# []
# []
# ['戲院', '睇戲', '煲劇', '電視劇', '香港']
# []
# []
# []
# ['公告']
# ['LOL', 'memes', '搞笑', 'Gag']
# ['荒野亂鬥']
# []
# []
# ['春聯', '紅包']
# ['狼人殺']
# []
# []
# []
# []
# []
# []
# ['進擊的巨人', '漫畫', '動畫']
# []
# []
# []
# ['社畜', '翻工', 'Intern', '搵工', '見工']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['香港', '二手']
# []
# []
# []
# []
# []
# ['午夜實驗室']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['餅乾', '公會', '薑餅人', '組隊']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['我是媽寶我驕傲', '曬媽媽', '母親節蛋糕', '康乃馨', '母親節花束', '我愛媽媽', '母親節禮物', '媽媽我愛你', '媽媽', '母親節大餐', '母親節檔期']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['ok']
# []
# []
# []
# []
# ['87節', '我八七我驕傲', '87']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['港聞', '正苦', '林鄭', '時事', '社會', '政治']
# []
# ['好玩', '港澳板', '生活', '日常']
# ['減肥', '護膚', '打扮', '搽面', '化妝', '分享']
# []
# []
# ['電玩', '動漫節', 'Cosplay', '動漫', 'ACG', '遊戲']
# []
# []

# %%
df.columns
# Out:
# Index(['alias', 'name', 'description', 'subscriptionCount', 'subscribed',
#        'read', 'createdAt', 'updatedAt', 'canPost', 'ignorePost', 'invisible',
#        'isSchool', 'fullyAnonymous', 'canUseNickname', 'postThumbnail',
#        'shouldCategorized', 'shouldPostCategorized', 'hasPostCategories',
#        'titlePlaceholder', 'postTitlePlaceholder', 'ipCountryCondition',
#        'subcategories', 'topics', 'nsfw', 'mediaThreshold', 'limitCountries',
#        'limitStage', 'availableLayouts', 'postCount', 'favorite',
#        'enablePrivateMessage', 'heroImage', 'logo'],
#       dtype='object')
